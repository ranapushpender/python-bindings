# %%
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(['docker','ps','-a'],stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    result = []
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8')))

    
        

class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers():
        result = createProcess(['docker','ps',-'a'])
        return result
    

#stream = os.popen('docker ps -a')
process = subprocess.Popen(['docker','ps','-a'],stderr=subprocess.PIPE,stdout=subprocess.PIPE)
stdout,stderr = process.communicate()
if(len(stderr.decode('UTF-8'))>0):
    print("Error")
else:
    text = stdout.decode('UTF-8')
    text = text.split('\n')
    text = text[1::]
    objs = []

    for index,line in enumerate(text):
        text[index] = text[index].split('  ')
        text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
        if(len(text[index])>0):
            objs.append(Container(text[index]))
            #print(objs[index].status)
print(objs[0].stop(['-f']))
# Out:
# ['docker', 'stop', '-f', 'fa4a09c8d092']

# %%
"""exit()
text = stream.read()
text = text.split('\n')
text = text[1::]
objs = []

for index,line in enumerate(text):
    text[index] = text[index].split('  ')
    text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
    if(len(text[index])>0):
        objs.append(Container(text[index]))"""

# %%
#create
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8'))>0)
        

class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers(self):
        result = createProcess(['docker','ps','-a'])
        objs = []
        if not result[2]:
            text = result[0]
            text = text.split('\n')
            text = text[1::]
            for index,line in enumerate(text):
                text[index] = text[index].split('  ')
                text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
                if(len(text[index])>0):
                    objs.append(Container(text[index]))
        return objs
    def findContainer(self,cid):
        containers = self.getContainers()
        for container in containers:
            if container.cid == cid:
                return container
        return None
    def createContainer(self,options):
        options = ['docker','run','-d']+options.split(' ')
        result = createProcess(options)
        return result
                

docker = Docker()
docker.getContainers()
for container in docker.getContainers():
    print(container.cid)
    
print("Single\n")
cont = docker.findContainer("cc1dsa0e5e0c5")
if cont!=None:
    print(cont.cid)
else:
    print("Not found")

res = docker.createContainer('--name mynginx1 -p ds8021:8021 nginx')
print("{} \n\n {}".format(res[0],res[1]))
# Out:
# fa4a09c8d092
# 4f66a0a22b28
# ff679cdfb8cf
# cc1da0e5e0c5
# f04496148d1f
# Single
#
# Not found
#
#
#  docker: invalid publish opts format (should be name=value but got 'ds8021:8021').
# See 'docker run --help'.

# %%
#Stop
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8'))>0)
        

class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
        
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)
        return process
    
    def start(self,options=[]):
        options = [program,'start']+options+[self.cid]
        process = createProcess(options)
        return process

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers(self):
        result = createProcess(['docker','ps','-a'])
        objs = []
        if not result[2]:
            text = result[0]
            text = text.split('\n')
            text = text[1::]
            for index,line in enumerate(text):
                text[index] = text[index].split('  ')
                text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
                if(len(text[index])>0):
                    objs.append(Container(text[index]))
        return objs
    def findContainer(self,cid):
        containers = self.getContainers()
        for container in containers:
            if container.cid == cid:
                return container
        return None
    def createContainer(self,options):
        options = ['docker','run','-d']+options.split(' ')
        result = createProcess(options)
        return result
                

docker = Docker()
container = docker.findContainer("efecdd13d6af")
container.stop()
for cont in docker.getContainers():
    print("{}  {}".format(cont.cid,cont.status))
# Out:
# cc419734b569   Exited (0) 23 seconds ago
# efecdd13d6af   Exited (0) Less than a second ago
# fa4a09c8d092  Up Less than a second
# 4f66a0a22b28  Up Less than a second
# ff679cdfb8cf  Up Less than a second
# cc1da0e5e0c5   Exited (137) 10 months ago
# f04496148d1f   Exited (137) 10 months ago

# %%
#Start
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8'))>0)
        

class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
        
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)
        return process
    
    def start(self,options=[]):
        options = [program,'start']+options+[self.cid]
        process = createProcess(options)
        return process
    
    def delete(self,options=[]):
        options = [program,'rm']+options+[self.cid]
        process = createProcess(options)
        return process

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers(self):
        result = createProcess(['docker','ps','-a'])
        objs = []
        if not result[2]:
            text = result[0]
            text = text.split('\n')
            text = text[1::]
            for index,line in enumerate(text):
                text[index] = text[index].split('  ')
                text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
                if(len(text[index])>0):
                    objs.append(Container(text[index]))
        return objs
    def findContainer(self,cid):
        containers = self.getContainers()
        for container in containers:
            if container.cid == cid:
                return container
        return None
    def createContainer(self,options):
        options = ['docker','run','-d']+options.split(' ')
        result = createProcess(options)
        return result
                

docker = Docker()
container = docker.findContainer("efecdd13d6af")
container.start()
for cont in docker.getContainers():
    print("{}  {}".format(cont.cid,cont.status))
# Out:
# cc419734b569   Exited (0) 3 minutes ago
# efecdd13d6af   Up Less than a second
# fa4a09c8d092  Up Less than a second
# 4f66a0a22b28  Up Less than a second
# ff679cdfb8cf  Up Less than a second
# cc1da0e5e0c5   Exited (137) 10 months ago
# f04496148d1f   Exited (137) 10 months ago

# %%
#Delete
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8'))>0)
        

class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
        
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)
        return process
    
    def start(self,options=[]):
        options = [program,'start']+options+[self.cid]
        process = createProcess(options)
        return process
    
    def delete(self,options=[]):
        self.stop()
        options = [program,'rm']+options+[self.cid]
        process = createProcess(options)
        return process

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers(self):
        result = createProcess(['docker','ps','-a'])
        objs = []
        if not result[2]:
            text = result[0]
            text = text.split('\n')
            text = text[1::]
            for index,line in enumerate(text):
                text[index] = text[index].split('  ')
                text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
                if(len(text[index])>0):
                    objs.append(Container(text[index]))
        return objs
    def findContainer(self,cid):
        containers = self.getContainers()
        for container in containers:
            if container.cid == cid:
                return container
        return None
    def createContainer(self,options):
        options = ['docker','run','-d']+options.split(' ')
        result = createProcess(options)
        return result
                

docker = Docker()
container = docker.findContainer("cc419734b569")
container.delete()
for cont in docker.getContainers():
    print("{}  {}".format(cont.cid,cont.status))
# Out:
# fa4a09c8d092  Up Less than a second
# 4f66a0a22b28  Up Less than a second
# ff679cdfb8cf  Up Less than a second
# cc1da0e5e0c5   Exited (137) 10 months ago
# f04496148d1f   Exited (137) 10 months ago

# %%
#Stats
import os
import subprocess

program = 'docker'
stop_command = 'stop'

def createProcess(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    stdout,stderr = process.communicate()
    return (stdout.decode('UTF-8'),stderr.decode('UTF-8'),len(stderr.decode('UTF-8'))>0)

def createProcessSingleine(options):
    process = subprocess.Popen(options,stderr=subprocess.PIPE,stdout=subprocess.PIPE)
    result = process.stdout.readline().decode('UTF-8')
    result = process.stdout.readline().decode('UTF-8')
    process.terminate()
    return result

    
class Container:
    def __init__(self,l):
        self.cid = l[0]
        self.image = l[1]
        self.status = l[4]
        #self.port = l[5]
        self.name = l[1]
        
    def stop(self,options=[]):
        options = [program,stop_command]+options+[self.cid]
        process = createProcess(options)
        return process
    
    def start(self,options=[]):
        options = [program,'start']+options+[self.cid]
        process = createProcess(options)
        return process
    
    def delete(self,options=[]):
        self.stop()
        options = [program,'rm']+options+[self.cid]
        process = createProcess(options)
        return process
    
    def stats(self):
        options = [program,'stats']+[self.cid]
        text = createProcessSingleine(options)
        text = text.split('  ')
        text = list(filter(lambda w : w!='' and w!=' ',text))
        return {
            "name" : text[1],
            "cpu" : text[2],
            "ram_limit" : text[3],
            "ram" : text[4],
            "io" :text[5],
            "block_io":text[6],
            "pid" : text[7]
            
        }
        

class Docker:
    def __init__(self):
        self.name="docker"
    def getContainers(self):
        result = createProcess(['docker','ps','-a'])
        objs = []
        if not result[2]:
            text = result[0]
            text = text.split('\n')
            text = text[1::]
            for index,line in enumerate(text):
                text[index] = text[index].split('  ')
                text[index] = list(filter(lambda element : element.rstrip()!='' and element.lstrip!='',text[index]))
                if(len(text[index])>0):
                    objs.append(Container(text[index]))
        return objs
    def findContainer(self,cid):
        containers = self.getContainers()
        for container in containers:
            if container.cid == cid:
                return container
        return None
    def createContainer(self,options):
        options = ['docker','run','-d']+options.split(' ')
        result = createProcess(options)
        return result
                

docker = Docker()
container = docker.findContainer("fa4a09c8d092")
stats = container.stats()
for key,value in stats.items():
    print("{} : {}".format(key,value))
container.start()
stats = container.stats()
for key,value in stats.items():
    print("{} : {}".format(key,value))
# Out:
# name : mstream-nodejs
# cpu : 0.00%
# ram_limit :  0B / 0B
# ram :  0.00%
# io :  0B / 0B
# block_io :  0B / 0B
# pid :  0
#
# name : mstream-nodejs
# cpu : 9.99%
# ram_limit :  106.7MiB / 15.61GiB
# ram :  0.67%
# io :  970B / 0B
# block_io :  0B / 0B
# pid :  7
